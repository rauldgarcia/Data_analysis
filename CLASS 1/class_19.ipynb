# %% [markdown]
# # Data Analysis
# ## Class 19
# ### Normal distribution
# #### November 15th

# %% [markdown]
# It's probability density function, pdf, is given mathematically by
#
# $\rho(x) = \frac{1}{\sigma \sqrt{2\pi}} \exp \left (-\frac{1}{2}\frac{(x-\mu)^2}{\sigma ^2} \right)$
#
# for any positive real number $\sigma, \sigma>0$ and any real number $\mu$.
#
# * $\mu$ is called the location parameter of the distribution
# * $\sigma$ the scale parameter

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
x_pdf = np.linspace(-5, 5, 250)
y_pdf = stats.norm.pdf(x_pdf, loc=0, scale=1)
n0 = plt.plot(x_pdf, y_pdf)

# %%
mu = 0
sig = 1

# %%
x = -10
stats.norm.pdf(x, loc=mu, scale=sig)
# Out:
# 7.69459862670642e-23

# %%
x = 10
stats.norm.pdf(x, loc=mu, scale=sig)
# Out:
# 7.69459862670642e-23

# %%
x = mu
stats.norm.pdf(x, loc=mu, scale=sig)
# Out:
# 0.3989422804014327

# %%
1/np.sqrt(2*np.pi)
# Out:
# 0.3989422804014327

# %%
x_pdf = np.linspace(-5, 5, 100)

# %% [markdown]
# Let's explore how the scale parameters changes the shape of the distribution

# %%
plt.plot(stats.norm.pdf(x_pdf, loc=0, scale=1), c='r')
sig = 0.5
plt.plot(stats.norm.pdf(x_pdf, loc=mu, scale=sig))

# %%
sig = 0.00125
x_pdf = np.linspace(-4*sig, 4*sig, 100)
plt.plot(stats.norm.pdf(x_pdf, loc=mu, scale=sig), c='g')

# %%
x_pdf = np.linspace(-5, 5, 100)
plt.plot(stats.norm.pdf(x_pdf, loc=0, scale=1), c='r')
sig = 0.5
plt.plot(stats.norm.pdf(x_pdf, loc=mu, scale=sig))

# %% [markdown]
# Evaluate the value of the function at $x = \sigma$

# %%
x_pdf = np.linspace(-4, 4, 250)
mu = 0.
sig = 1
plt.axvline(mu)
plt.plot(x_pdf, stats.norm.pdf(x_pdf, loc=mu, scale=sig), c='r')
fs = stats.norm.pdf(sig, loc=mu, scale=sig)
plt.axvline(sig, c='k')
plt.axhline(fs, c='k')

plt.axvline(2*sig, c='k')
plt.axhline(stats.norm.pdf(2*sig, loc=mu, scale=sig), c='k')

plt.axvline(3*sig, c='k')
plt.axhline(stats.norm.pdf(3*sig, loc=mu, scale=sig), c='k')

# %%
norm = stats.norm()

# %%
y_pdf=stats.norm.pdf(x_pdf, loc=mu, scale=sig)
stats.kurtosis(y_pdf)
stats.skew(y_pdf)
# Out:
# 0.7938687549694613

# %%
sns.histplot(norm.rvs(size=1000))
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
df = pd.DataFrame(norm.rvs(size=1000))
df
# Out:
#             0
# 0    0.182242
# 1   -1.418204
# 2    2.318487
# 3   -0.307698
# 4    0.494109
# ..        ...
# 995  0.251794
# 996  0.524594
# 997 -0.025066
# 998  1.801164
# 999 -0.224853
#
# [1000 rows x 1 columns]

# %%
s = 100000
df = pd.DataFrame(norm.rvs(size=s))
len(df[(0<df[0]) & (df[0]<1)])/s
# Out:
# 0.34514

# %%
df = pd.DataFrame(norm.rvs(size=s))
len(df[(0<df[0]) & (df[0]<2)])/s
# Out:
# 0.47903

# %%
df = pd.DataFrame(norm.rvs(size=s))
len(df[(0<df[0]) & (df[0]<3)])/s
# Out:
# 0.49917

# %%
0.47679-0.33934
# Out:
# 0.13745000000000002

# %%
len(df[(1<df[0]) & (df[0]<2)])/s
# Out:
# 0.13423

# %%
0.48776 - 0.47679
# Out:
# 0.010970000000000035

# %%
len(df[(2<df[0]) & (df[0]<3)])/s
# Out:
# 0.02122

# %%
norm = stats.norm(loc=15, scale=3)
sam = norm.rvs(s)
sns.histplot(sam)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
sns.histplot(sam)
sns.histplot(sam-sam.mean())
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
sam.std()
# Out:
# 2.9934155889882903

# %%
(sam-sam.mean()).std()
# Out:
# 2.9934155889882903

# %%
sns.histplot(sam)
sns.histplot(sam-sam.mean())
sns.histplot((sam-sam.mean())/sam.std())
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
sns.histplot((sam-sam.mean())/sam.std(), color='g')
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
beta = stats.beta(2, 2)

# %%
sam1 = beta.rvs(s)
sns.histplot(sam1)
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
sns.histplot(sam1)
sns.histplot(sam1-sam1.mean())
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
sam1.mean()
# Out:
# 0.5002717037357156

# %%
sam1.std()
# Out:
# 0.22427879846279142

# %%
beta.stats()
# Out:
# (array(0.5), array(0.05))

# %%
np.sqrt(0.05)
# Out:
# 0.22360679774997896

# %%
sns.histplot(sam1)
sns.histplot(sam1-sam1.mean(), color='r')
sns.histplot((sam1-sam1.mean())/sam1.std(), color='y')
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
sns.histplot((sam1-sam1.mean())/sam1.std(), color='y')
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
z = (sam1-sam1.mean())/sam1.std()
z.mean()
# Out:
# 1.3994139180795174e-16

# %%
z.std()
# Out:
# 1.0
